# %%
#Import dependencies
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
#read in csv dta
df = pd.read_csv('myopia.csv')
df
# Out:
#      AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0      6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1      6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2      6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3      6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4      5  0.697  23.290001  3.676  3.454  16.16       14       0       0
# ..   ...    ...        ...    ...    ...    ...      ...     ...     ...
# 613    6  0.678  22.400000  3.663  3.803  14.93        2       0       7
# 614    6  0.665  22.500000  3.570  3.378  15.56        6       0       1
# 615    6  1.834  22.940001  3.624  3.424  15.89        8       0       0
# 616    6  0.665  21.920000  3.688  3.598  14.64       12       2       1
# 617    6  0.802  22.260000  3.530  3.484  15.25       25       0       2
#
#      STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY  MYOPIC
# ...

# %%
#Drop Myopic column
df.drop(columns=['MYOPIC'], inplace=True)
df
# Out:
#      AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0      6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1      6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2      6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3      6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4      5  0.697  23.290001  3.676  3.454  16.16       14       0       0
# ..   ...    ...        ...    ...    ...    ...      ...     ...     ...
# 613    6  0.678  22.400000  3.663  3.803  14.93        2       0       7
# 614    6  0.665  22.500000  3.570  3.378  15.56        6       0       1
# 615    6  1.834  22.940001  3.624  3.424  15.89        8       0       0
# 616    6  0.665  21.920000  3.688  3.598  14.64       12       2       1
# 617    6  0.802  22.260000  3.530  3.484  15.25       25       0       2
#
#      STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY
# 0          0    10         34      1      1
# ...

# %%
#Scale data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df)
X_scaled.shape
# Out:
# (618, 14)

# %%
#Apply Dimensionality Reduction
pca = PCA(n_components=.9)
pca.fit(X_scaled)
principal_components = pca.transform(X_scaled)
principal_components.shape
# Out:
# (618, 10)

# %%
#preserve 90% of the explained variance in dimensionality reduction
pca.explained_variance_ratio_.sum()
# Out:
# 0.9187361702915187

# %%
#Further reduce the dataset dimensions with t-SNE and visually inspect the results
tsne = TSNE(perplexity=50)
features = tsne.fit_transform(principal_components)
features.shape
# Out:
# C:\Users\Paul Distasi\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\Paul Distasi\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# (618, 2)

# %%
#Create a scatter plot of the t-SNE output
plt.scatter(features[:,0], features[:,1])

# %% [markdown]
# ### There appears to be 4 disctinct clusters from the scatter plot results

# %%
#Use a for loop to determine the inertia for each k between 1 through 10.
inertia = list()
k = list(range(1,9))

for i in k:
    km = KMeans(n_clusters=i, random_state=42)
    km.fit(principal_components)
    inertia.append(km.inertia_)
    
elbow_df = pd.DataFrame({'k': k, 'inertia': inertia})
# Out:
# C:\Users\Paul Distasi\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(

# %%
#Create an elbow plot to identify the best number of clusters
elbow_df.plot.line(x='k', y='inertia')
plt.ylabel('Inertia')
plt.title('Elbow Plot')
# Out:
# Text(0.5, 1.0, 'Elbow Plot')

# %% [markdown]
# ### According to the above elbow graph, the patients can be clustered into 3 to 4 separate groups.
